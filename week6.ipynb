# %% [markdown]
# Activity 1
# Displaying multiple images in Python

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
img_filenames = os.listdir('data')
imgs = [mpimg.imread(os.path.join('data', img_filename)) for img_filename in img_filenames]

# %%
fig, axes = plt.subplots(2, 2)
fig.figsize = (6, 6)
fig.dpi = 150
axes = axes.ravel()
# Specify labels
labels = ['coast', 'beach', 'building', 'city at night']
# Plot images
for i in range(len(imgs)):
    axes[i].imshow(imgs[i])
    axes[i].set_xticks([])
    axes[i].set_yticks([])
    axes[i].set_xlabel(labels[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-df9f7b9b7d7c> in <module>
#       7 # Plot images
#       8 for i in range(len(imgs)):
# ----> 9     axes[i].imshow(imgs[i])
#      10     axes[i].set_xticks([])
#      11     axes[i].set_yticks([])
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %% [markdown]
# Activity 2: Visualising Colour Spaces of images with Python
# [link text](https://dev.to/codesphere/visualizing-the-color-spaces-of-images-with-python-and-matplotlib-1nmk)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from PIL import Image

# %%
im = Image.open("data/colourSpaces.jpeg")

# %%
px = im.load()

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x206 at 0x7F919328DDD0>

# %%
print(px)

# %%
ax = plt.axes(projection = '3d')

# %%
print(ax)
# Out:
# Axes3DSubplot(0.125,0.125;0.775x0.755)

# %%
# Question 1) create an empty matrix for each coordinate as well as the colour.
x = []
y = []
z = []
c = []

# %%
'''
for row in range(0, im.height):
  for col in range(0, im.width):
    pix = px[col,row]
    #pix_x = x[col,row]

'''
for row in range(0,im.height):
       for col in range(0, im.width):
            pix = px[col,row]
            x.append(pix[0])
            y.append(pix[1])
            z.append(pix[2])
            c.append((pix[0] / 255, pix[1] / 255, pix[2] / 255))

# %%
pix
# Out:
# (101, 83, 61)

# %%
print(px)

# %%
# Question 2) normalize the RGB values between 0 and 1 when providing colors.
 #        // add your answer here
newCol = (pix[0] / 255, pix[1] / 255, pix[2] / 255)
if(not newCol in c):
  x.append(pix[0])
  y.append(pix[1])
  z.append(pix[2])
  c.append(newCol)


for row in range(0,im.height):
     for col in range(0, im.width):
         pix = px[col,row]
         newCol = (pix[0] / 255, pix[1] / 255, pix[2] / 255)

         if(not newCol in c):
            x.append(pix[0])
            y.append(pix[1])
            z.append(pix[2])
            c.append(newCol)

# %%
ax.scatter(x,y,z, c = c)
plt.show()

# %%
# https://dev.to/codesphere/visualizing-the-color-spaces-of-images-with-python-and-matplotlib-1nmk
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from PIL import Image

im = Image.open("/content/data/colourSpaces.jpeg")
px = im.load()

ax = plt.axes(projection = '3d')
x = []
y = []
z = []
c = []

for row in range(0,im.height):
     for col in range(0, im.width):
         pix = px[col,row]
         newCol = (pix[0] / 255, pix[1] / 255, pix[2] / 255)

         if(not NewCol in c):
            x.append(pix[0])
            y.append(pix[1])
            z.append(pix[2])
            c.append(newCol)

ax.scatter(x,y,z, c = c)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-04e8f6f12347> in <module>
#      18          newCol = (pix[0] / 255, pix[1] / 255, pix[2] / 255)
#      19
# ---> 20          if(not NewCol in c):
#      21             x.append(pix[0])
#      22             y.append(pix[1])
#
# NameError: name 'NewCol' is not defined

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from PIL import Image
im = Image.open("/content/data/colourSpaces.jpeg")
px = im.load()
ax = plt.axes(projection = '3d')
x = []
y = []
z = []
c = []
for rw in range(0,im.height):
       for col in range(0, im.width):
            pix = px[col,row]
            x.append(pix[0])
            y.append(pix[1])
            z.append(pix[2])
            c.append((pix[0] / 255, pix[1] / 255, pix[2] / 255))

for row in range(0,im.height):
     for col in range(0, im.width):
         pix = px[col,row]
         newCol = (pix[0] / 255, pix[1] / 255, pix[2] / 255)

         if(not newCol in c):
            x.append(pix[0])
            y.append(pix[1])
            z.append(pix[2])
            c.append(newCol)
ax.scatter(x,y,z, c = c)
plt.show()
